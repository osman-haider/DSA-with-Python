# %% [markdown]
# ![image.png](attachment:92217941-a9ef-4d5a-a710-2e5b6eb0078b.png)

# %%
def coinChange(totalNumber, coins):
    N = totalNumber
    coins.sort()
    index = len(coins)-1
    while True:
        coinValue = coins[index]
        if N >= coinValue:
            print(coinValue)
            N = N - coinValue
        if N < coinValue:
            index -= 1
        
        if N == 0:
            break

# %%
coins = [1,2,5,20,50,100]
coinChange(201, coins)
# Out:
# 100
# 100
# 1
