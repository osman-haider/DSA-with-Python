# %% [markdown]
# ![image.png](attachment:98a1c903-7283-4464-97da-d1a00c6647a0.png)

# %% [markdown]
# ![image.png](attachment:4e7f8522-cf63-48da-bb24-7b4a1ad994f1.png)

# %%
def houseRobber(houses, currentIndex):
    if currentIndex >= len(houses):
        return 0
    else:
        stealFirstHouse = houses[currentIndex] + houseRobber(houses, currentIndex + 2)
        skipFirstHouse = houseRobber(houses, currentIndex+1)
        return max(stealFirstHouse, skipFirstHouse)

# %%
houses = [6,7,1,30,8,2,4]
print(houseRobber(houses, 1))
# Out:
# 41
